# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.127-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.127-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.4 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.5 MB/s eta 0:00:00:00:0100:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.127 ultralytics-thop-2.0.14

# %%
# !gdown 1GSAF_u7Gxz0Wcxjd-7zL1Gd2WfC0s7Zz
# !unzip wind-turbine-damage-challenges.zip
# !rm wind-turbine-damage-challenges.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1GSAF_u7Gxz0Wcxjd-7zL1Gd2WfC0s7Zz
# From (redirected): https://drive.google.com/uc?id=1GSAF_u7Gxz0Wcxjd-7zL1Gd2WfC0s7Zz&confirm=t&uuid=902b8aab-97e8-4fc8-a22f-b0ff39474975
# To: /kaggle/working/wind-turbine-damage-challenges.zip
# 100%|██████████████████████████████████████| 1.58G/1.58G [00:16<00:00, 93.4MB/s]
# Archive:  wind-turbine-damage-challenges.zip
#   inflating: Wind Turbine damage/README.roboflow.txt
#   inflating: Wind Turbine damage/test/20240120_150729_jpg.rf.5925f54483de8cc52f75fdd1dc0ec3a0.jpg
#   inflating: Wind Turbine damage/test/20240120_153628_jpg.rf.67030e3c4592587d26d7762e8e091020.jpg
#   inflating: Wind Turbine damage/test/20240120_153658_jpg.rf.66dc04dc4ee8194ccc19397d4ad42f2e.jpg
#   inflating: Wind Turbine damage/test/20240120_153711_jpg.rf.3a50aa9daa881abe4296c7f12b03fcf9.jpg
#   inflating: Wind Turbine damage/test/20240120_153748-0-_jpg.rf.6c50a8089bf3ccd32bb61e347e9f4019.jpg
#   inflating: Wind Turbine damage/test/20240120_153754_jpg.rf.01e099db13ef7c0beee133daa6379466.jpg
#   inflating: Wind Turbine damage/test/20240120_153843-0-_jpg.rf.60b55d7dd594d0869bf7216a34d16385.jpg
#   inflating: Wind Turbine damage/test/20240120_153843_jpg.rf.b24d413669fa575889018912a2b372e9.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0000_jpg.rf.66e7e87b86904e97508657a58ba9972c.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0015_jpg.rf.62ada8738a17b071f5859ef2ba587652.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0034_jpg.rf.32c6d4c6f0fe3e919f7db3fea5d74dca.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0061_jpg.rf.ea7113440055cbce048892f47f14cd42.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0075_jpg.rf.82235fee115b78aac2460ceb4f6758a0.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0077_jpg.rf.17e71709fd53ea08911fdec60dd0f3df.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0079_jpg.rf.ed1b222a0cf341a04f27bcdc26a65687.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0081_jpg.rf.47e59973cbd4e1f40363bf218c380254.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0084_jpg.rf.de984895faf812264c6c6a416eb62e02.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0086_jpg.rf.1d43d0c9b738b921d5601116df4d1965.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0088_jpg.rf.ef0c44646fd1469ebacc82989015336b.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0095_jpg.rf.40c05c5950a48627a9add8cb56d60ca9.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0110_jpg.rf.a5ed327b0bb16f8bc19802aab18f92f0.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0126_jpg.rf.5a9e67fd5bce7969a5775f6ff5273805.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0134_jpg.rf.5aa81e12178bd71422c009b29fde0726.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0149_jpg.rf.45490f1c8ade5580d1279140588b187b.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0155_jpg.rf.2ae5c8fbaa05347ec7fd8a91a06defe3.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0160_jpg.rf.94f5e7408084ab5c0e36cec28179010d.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0162_jpg.rf.8b7f8d55232f8cb9ddf65739df72e6a7.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0169_jpg.rf.5e1be9ba9931db503f8f947f84fe617c.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0181_jpg.rf.66646f9753d87d16a241d1a3e292f0b6.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0191_jpg.rf.f484f72de307f2e534029f265407a11a.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0194_jpg.rf.d159889f8505128041a06c158de5722c.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0197_jpg.rf.441cee5d1329381499818d23066115d8.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0202_jpg.rf.635e5d1d6357a368cd07285e3859f2f4.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0214_jpg.rf.3c67777e183c90e06f84a4c5b9115c0d.jpg
#   inflating: Wind Turbine damage/test/20240120_155211_mp4-0222_jpg.rf.10d6752c3fb32b117287db9cb9ba6e0b.jpg
#   inflating: Wind Turbine damage/test/20240120_160457-0-_jpg.rf.609b8e725f177836e00fd543f6d92f73.jpg
#   inflating: Wind Turbine damage/test/20240120_160553_jpg.rf.02cafabaceab373ddc1e5c30e1ba8499.jpg
#   inflating: Wind Turbine damage/test/20240120_160557_jpg.rf.4d9909256e4bcb526d3eb1b63082b093.jpg
#   inflating: Wind Turbine damage/test/20240120_160706-0-_jpg.rf.8582ddb4316cf299a51bcb10f58e36a5.jpg
#   inflating: Wind Turbine damage/test/20240120_160706_jpg.rf.6b2e2b4a13dc2e6d5946abcebccaa874.jpg
#   inflating: Wind Turbine damage/test/20240120_160957_jpg.rf.5155c81578046677bece204ddb26c09d.jpg
#   inflating: Wind Turbine damage/test/20240120_161014_jpg.rf.a886dd45473612fae63ab4fed235c9de.jpg
#   inflating: Wind Turbine damage/test/20240120_161017_jpg.rf.951c430467f8f672bd6885680ab7dadc.jpg
#   inflating: Wind Turbine damage/test/20240120_161023_jpg.rf.1af5fe6c0ba91aacdc8502f9365d62dc.jpg
#   inflating: Wind Turbine damage/test/20240120_161103-0-_jpg.rf.7ac8bc94eb0190afc02b4a4ceab49ac1.jpg
#   inflating: Wind Turbine damage/test/20240120_161118_jpg.rf.c474047ad5d392415971b82ea2691ff5.jpg
#   inflating: Wind Turbine damage/test/20240120_161126_jpg.rf.af941467cefb044aa50ac875b6bdc0e8.jpg
#   inflating: Wind Turbine damage/test/20240120_161133-0-_jpg.rf.dcddf116ed0ce393efa094713138319c.jpg
#   inflating: Wind Turbine damage/test/20240120_161134-0-_jpg.rf.bdb581aa01a6efc955bd97285dbd74e1.jpg
#   inflating: Wind Turbine damage/test/20240120_161207_jpg.rf.b811af46b8e7c338c1ffaabeb5cf66bb.jpg
#   inflating: Wind Turbine damage/test/20240120_161228_jpg.rf.8551f713d2a16451aa3ba4c2b155e00b.jpg
#   inflating: Wind Turbine damage/test/20240120_162824_jpg.rf.a51b12875976d0bffc12c06581c56936.jpg
#   inflating: Wind Turbine damage/test/20240120_162828-1-_jpg.rf.4fdac321731d4d3db13d4b820258854b.jpg
#   inflating: Wind Turbine damage/test/20240120_162838_jpg.rf.306512a3b2d96f18f9dea28941d46350.jpg
#   inflating: Wind Turbine damage/test/20240120_162844-0-_jpg.rf.9b6edc74a2607728b200221a9fdc546b.jpg
#   inflating: Wind Turbine damage/test/20240120_162844-1-_jpg.rf.c25211b4ab0af41936afc89d5946f32b.jpg
#   inflating: Wind Turbine damage/test/20240120_162851-0-_jpg.rf.5becbe16d62094a5106285708a1ec473.jpg
#   inflating: Wind Turbine damage/test/20240120_162905-0-_jpg.rf.cec91a04d4d97418ef532934b05aa31d.jpg
#   inflating: Wind Turbine damage/test/20240120_162912-0-_jpg.rf.3d1a61f602d2413278b9f6cb2f8f111f.jpg
#   inflating: Wind Turbine damage/test/20240120_162914-0-_jpg.rf.f59673051fd81362e6b0d7794bab432b.jpg
#   inflating: Wind Turbine damage/test/20240120_162955-0-_jpg.rf.1495715f852a7fff8456e044dd26cc11.jpg
#   inflating: Wind Turbine damage/test/20240120_163003-1-_jpg.rf.e256f36bd594cafc2041415d9a119600.jpg
#   inflating: Wind Turbine damage/test/20240120_163005-0-_jpg.rf.ab8c91946df2390ab574f5de89fba09e.jpg
#   inflating: Wind Turbine damage/test/20240120_163020-0-_jpg.rf.e503792ced04bce579305e19fa3a485c.jpg
#   inflating: Wind Turbine damage/test/20240120_163021-0-_jpg.rf.2b48f3937dc7bd85cc5b2570c331b0fe.jpg
#   inflating: Wind Turbine damage/test/20240120_163033-0-_jpg.rf.baf4645828be43c72d9e8fcfc24b64b5.jpg
#   inflating: Wind Turbine damage/test/20240120_163038_jpg.rf.dc1643fa88e3f647d7664ce37a39f3fe.jpg
#   inflating: Wind Turbine damage/test/20240120_163040-0-_jpg.rf.9a6a8c19c726628a53bd9f5db3f2f439.jpg
#   inflating: Wind Turbine damage/test/20240120_163044_jpg.rf.9d8b6fcd8b4cbab86c02647c41f007d5.jpg
#   inflating: Wind Turbine damage/test/20240120_163045-0-_jpg.rf.ee9cb8ff7b1709019cea1ed609b67d2f.jpg
#   inflating: Wind Turbine damage/test/20240120_163052_jpg.rf.111fcd1bad265aa0c2447269bca9a49a.jpg
#   inflating: Wind Turbine damage/test/20240120_163053-1-_jpg.rf.d5e4b0912ebe72247db35232ba3fffdd.jpg
#   inflating: Wind Turbine damage/test/20240120_163054_jpg.rf.9456e409d5d472605b41e51c47f80d04.jpg
#   inflating: Wind Turbine damage/test/20240120_163623_jpg.rf.dadee9dfb41e95b4016dd97010437f84.jpg
#   inflating: Wind Turbine damage/test/20240120_163626_jpg.rf.bb15a2c995255433bb8e8aabcd91c8b5.jpg
#   inflating: Wind Turbine damage/test/20240120_163642_jpg.rf.a184fefcd0f1c68991113d7b4d82cf0c.jpg
#   inflating: Wind Turbine damage/test/20240120_163644-0-_jpg.rf.968f7d72ae7be6ef8733b42490c03aed.jpg
#   inflating: Wind Turbine damage/test/20240120_163650-0-_jpg.rf.6ff26d6832686600c6f18b4be821482e.jpg
#   inflating: Wind Turbine damage/test/20240120_163650_jpg.rf.d420c98f550cdddfdcf15388a6232091.jpg
#   inflating: Wind Turbine damage/test/20240120_163730-0-_jpg.rf.7139d077e629ae78b03081e5ca84dd98.jpg
#   inflating: Wind Turbine damage/test/20240120_164156_jpg.rf.271c749cefc88f123dd383e89b32dfed.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-2330_jpg.rf.99f885a1881dee8e72b0e2cc91350290.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-2500_jpg.rf.f8151151ee2c00ac3ff469cadc42e2dc.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4110_jpg.rf.bc5bdabb1f57eb50d3bd4098c921d1fd.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4114_jpg.rf.5fa408a4c5bfd3b186f2a54dc555e753.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4148_jpg.rf.816f4ef4d1de664e9f6fcc45f6dfa11f.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4186_jpg.rf.acc31c48a0599af4ab5b90bf6b4a6136.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4190_jpg.rf.35c7cf908606d69f9e88e50415690b7f.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4714_jpg.rf.ab56dbe039b90c154f6ebacce19869f1.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4724_jpg.rf.db7990b2d0a32e3af5930cb8d63704b6.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4758_jpg.rf.7ec5f576a67700199ac4c7e897253413.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4881_jpg.rf.4682e343f5944b5f911d891965f0b6d8.jpg
#   inflating: Wind Turbine damage/test/20240120_164348_mp4-4909_jpg.rf.c2880db9ff2ebe752daa97bc61d1b947.jpg
#   inflating: Wind Turbine damage/test/DJI_0685-1-_JPG.rf.28e5acd6707444bdffa08e561f9b676b.jpg
#   inflating: Wind Turbine damage/test/DJI_0689-1-_JPG.rf.fa20919f9ea6451ed2d49be4f6f58f08.jpg
#   inflating: Wind Turbine damage/test/DJI_0694-1-_JPG.rf.b82a3198da2abe3ac2509df4a524d049.jpg
#   inflating: Wind Turbine damage/test/DJI_0695-1-_JPG.rf.a246dba06279f2c5e22e99852bcbbb99.jpg
#   inflating: Wind Turbine damage/test/DJI_0700-1-_JPG.rf.5959c97c6fecf8a47de229ce1efd54a3.jpg
#   inflating: Wind Turbine damage/test/DJI_0702-1-_JPG.rf.eb0e2024c06c73aec47ff061322e5159.jpg
#   inflating: Wind Turbine damage/test/DJI_0703-1-_JPG.rf.f37e56bcbcea4be50fbb69163950b25e.jpg
#   inflating: Wind Turbine damage/test/DJI_0704-1-_JPG.rf.60db0f08429e9bc32a75f95e3ee2d118.jpg
#   inflating: Wind Turbine damage/test/DJI_0706-1-_JPG.rf.266efc3b31622fd7c6e2043e77815f0f.jpg
#   inflating: Wind Turbine damage/test/DJI_0713-1-_JPG.rf.d5f2b2b8460d6addaded7f49160182be.jpg
#   inflating: Wind Turbine damage/test/DJI_0719-1-_JPG.rf.875b60e2f99c3faa08041c475b4e99ba.jpg
#   inflating: Wind Turbine damage/test/DJI_0724-1-_JPG.rf.6a190fc02e39550aab35e08235f34f30.jpg
#   inflating: Wind Turbine damage/test/DJI_0727-1-_JPG.rf.1ba9bf8c97c13eca16e3840a2f576076.jpg
#   inflating: Wind Turbine damage/test/DJI_0728-1-_JPG.rf.55ae4b479b0e282856186143e1fbbe72.jpg
#   inflating: Wind Turbine damage/test/DJI_0735-1-_JPG.rf.c2b5abc13f2bb4a92bbe500391cd6e2f.jpg
#   inflating: Wind Turbine damage/test/DJI_0736-1-_JPG.rf.91063e4bfc57903ac1c1a3e62eeae0e0.jpg
#   inflating: Wind Turbine damage/test/DJI_0738-1-_JPG.rf.38dac02166d65ecaf77d9c7babd45d4f.jpg
#   inflating: Wind Turbine damage/test/DJI_0739-1-_JPG.rf.773353bbf8434865979f18dfd494cfb1.jpg
#   inflating: Wind Turbine damage/test/DJI_0740-1-_JPG.rf.ab961f1d9d46ff49368e7edb5c8aead4.jpg
#   inflating: Wind Turbine damage/test/DJI_0747-1-_JPG.rf.4e371df6acba379f00cee896d44c5536.jpg
#   inflating: Wind Turbine damage/test/DJI_0748-1-_JPG.rf.0d8420a917a8186fa103932f63c7b501.jpg
#   inflating: Wind Turbine damage/test/DJI_0749-1-_JPG.rf.356be7f5b3ec7e31c5594426b6aba5eb.jpg
#   inflating: Wind Turbine damage/test/DJI_0751-1-_JPG.rf.3ce670d8f2209ef6c78270a89b642fba.jpg
#   inflating: Wind Turbine damage/test/DJI_0752-1-_JPG.rf.a82cba01167ad4cf275b98e201de6601.jpg
#   inflating: Wind Turbine damage/test/DJI_0753-1-_JPG.rf.7b2ffc0f3cdeacc24f83ad692cade3f6.jpg
#   inflating: Wind Turbine damage/test/DJI_0755-1-_JPG.rf.5cc110a79566dd9ab3ab412e985a33da.jpg
#   inflating: Wind Turbine damage/test/DJI_0756-1-_JPG.rf.e06774dbaeadae553f8a5707f33b59df.jpg
#   inflating: Wind Turbine damage/test/DJI_0757-1-_JPG.rf.55e66031eb54e212c90c8c7d09065a73.jpg
#   inflating: Wind Turbine damage/test/DJI_0758-1-_JPG.rf.4ccae74fb152cab9f4899aea4b7002ff.jpg
#   inflating: Wind Turbine damage/test/DJI_0762-1-_JPG.rf.ad96cbe9564933c045e82407f8379d47.jpg
#   inflating: Wind Turbine damage/test/DJI_0764-1-_JPG.rf.dda28e9da6a04fb32538af96498b7b55.jpg
#   inflating: Wind Turbine damage/test/DJI_0765-1-_JPG.rf.500d5a743566278e0be2d7cd60ce180c.jpg
#   inflating: Wind Turbine damage/test/DJI_0766-1-_JPG.rf.23aa70af0a4a9b9557902b4207972685.jpg
#   inflating: Wind Turbine damage/test/DJI_0767-1-_JPG.rf.6bf30033ae02a537b4dc2a335dc1ba98.jpg
#   inflating: Wind Turbine damage/test/DJI_0769-1-_JPG.rf.fc54d0bf4a5c1e1a7c32533f01a4b287.jpg
#   inflating: Wind Turbine damage/test/DJI_0771_JPG.rf.ef6771f47ce45dac8789ea590c7c9f88.jpg
#   inflating: Wind Turbine damage/test/DJI_0774_JPG.rf.4e79666308c10060b119179e067f6b5f.jpg
#   inflating: Wind Turbine damage/test/DJI_0775_JPG.rf.559241cce67f8a1b9d038bd9a07d73ad.jpg
#   inflating: Wind Turbine damage/test/DJI_0782_JPG.rf.20122d86e06af6481889f80a37481234.jpg
#   inflating: Wind Turbine damage/test/DJI_0783_JPG.rf.064314252ff22a8de6b1a64e759ced69.jpg
#   inflating: Wind Turbine damage/test/DJI_0786_JPG.rf.8393511dd03727861777c834fdfd3d93.jpg
#   inflating: Wind Turbine damage/test/DJI_0787_JPG.rf.b33e0b3720d9ad9f30ece0e2ce4fb2ab.jpg
#   inflating: Wind Turbine damage/test/DJI_0788_JPG.rf.2460e49d3538464c7bab22faf38f32e8.jpg
#   inflating: Wind Turbine damage/test/DJI_0789_JPG.rf.6e8cb81795ced0a81ad14f33ca8d26bc.jpg
#   inflating: Wind Turbine damage/test/DJI_0975_JPG.rf.37c894ef2602f302978e698b1cd65746.jpg
#   inflating: Wind Turbine damage/test/DJI_0978_JPG.rf.31c2820f9214cfe6e1c0279d732e9ec1.jpg
#   inflating: Wind Turbine damage/test/DJI_0979_JPG.rf.95e4156ad7c15913188dc03681b81e5a.jpg
#   inflating: Wind Turbine damage/test/DJI_0980_JPG.rf.9aae1abc3fdead93968f7a06073e9b87.jpg
#   inflating: Wind Turbine damage/test/DJI_0981_JPG.rf.49d83249cf60fcac1705593e4a86258b.jpg
#   inflating: Wind Turbine damage/test/DJI_0985_JPG.rf.aa69ccc4ef0830be243fc06f42e91c53.jpg
#   inflating: Wind Turbine damage/test/DJI_0987_JPG.rf.c2002d99afd301f941c19bd6e56a916a.jpg
#   inflating: Wind Turbine damage/test/DJI_0989_JPG.rf.c88276836792084a0205e542b79fb91c.jpg
#   inflating: Wind Turbine damage/test/DJI_0991_JPG.rf.54622f4cc224fae47bb990abe7a57d51.jpg
#   inflating: Wind Turbine damage/test/DJI_0992_JPG.rf.8adbc7b8fa4895501467ea9eaf53f0d4.jpg
#   inflating: Wind Turbine damage/test/DJI_0993_JPG.rf.f33b6663ee70d58a17f1b41a031a28c7.jpg
#   inflating: Wind Turbine damage/test/DJI_0994_JPG.rf.e5bf13e77518256c8c3f6ae62f9612b7.jpg
#   inflating: Wind Turbine damage/test/DJI_0995_JPG.rf.09f70312420808da47c3a4aaf186ca92.jpg
#   inflating: Wind Turbine damage/test/DJI_0997_JPG.rf.9f5f2b599b0927db0d1121a39516f4e0.jpg
#   inflating: Wind Turbine damage/train/20240120_150724_jpg.rf.d10477a0552d30811fc800c5843e81d2.jpg
#   inflating: Wind Turbine damage/train/20240120_150725_jpg.rf.7d3b2a99c968d20e419284a6f87e9177.jpg
#   inflating: Wind Turbine damage/train/20240120_150726_jpg.rf.91473860d293650156446feb0edc4920.jpg
#   inflating: Wind Turbine damage/train/20240120_150738_jpg.rf.88291581b6c6203bcc65c02949da285e.jpg
#   inflating: Wind Turbine damage/train/20240120_150742_jpg.rf.51f2dcc8c5ea73db56a3cd9515123f3c.jpg
#   inflating: Wind Turbine damage/train/20240120_150747_jpg.rf.9d192cee671a205d1e266625d2cec77d.jpg
#   inflating: Wind Turbine damage/train/20240120_150808_jpg.rf.6059a70e24ed4c3cba8c3a1fc173fe46.jpg
#   inflating: Wind Turbine damage/train/20240120_151455_jpg.rf.59a91b0a0942193116791ed32f733b76.jpg
#   inflating: Wind Turbine damage/train/20240120_151500_jpg.rf.bd3c5e06602ff1967bf0f7467c0c916f.jpg
#   inflating: Wind Turbine damage/train/20240120_151558-0-_jpg.rf.91b1d0dcabd60b0dda6e84ccb8c8b8be.jpg
#   inflating: Wind Turbine damage/train/20240120_151559_jpg.rf.b41ca4fe22c888449cd62119fc7dca5d.jpg
#   inflating: Wind Turbine damage/train/20240120_151603_jpg.rf.59b85bf6062d93a6d5244106d254d3ec.jpg
#   inflating: Wind Turbine damage/train/20240120_151605_jpg.rf.a902a26a4bfb20980185c311fc5167a1.jpg
#   inflating: Wind Turbine damage/train/20240120_151611_jpg.rf.83b4134926dbd344a007fa1e9f8b6612.jpg
#   inflating: Wind Turbine damage/train/20240120_151613_jpg.rf.1173be64e9af56032c55d4adc0718e4e.jpg
#   inflating: Wind Turbine damage/train/20240120_151628_jpg.rf.cb6d8cabbca71badac3d3cb3168276e7.jpg
#   inflating: Wind Turbine damage/train/20240120_151645_jpg.rf.f419d27b41e1455cfb3a7feecf3892c8.jpg
#   inflating: Wind Turbine damage/train/20240120_151650_jpg.rf.6e6ae405e94f4d20d5ccbb8028c179f4.jpg
#   inflating: Wind Turbine damage/train/20240120_151657_jpg.rf.af11c0a57810ec3f8a8e6d8dd09de597.jpg
#   inflating: Wind Turbine damage/train/20240120_151659_jpg.rf.43bcd445e7282645f85375e555068ff1.jpg
#   inflating: Wind Turbine damage/train/20240120_153602_jpg.rf.85661d6881ebbe8e105358916828b5eb.jpg
#   inflating: Wind Turbine damage/train/20240120_153622_jpg.rf.cc76d40e78bd2054d0dee915889c1147.jpg
#   inflating: Wind Turbine damage/train/20240120_153634_jpg.rf.0172073b762d413fc4e879e4e53f6721.jpg
#   inflating: Wind Turbine damage/train/20240120_153652_jpg.rf.90d475fce5b76aa109e26562a9d297da.jpg
#   inflating: Wind Turbine damage/train/20240120_153701_jpg.rf.ead6c94da24059a10f06dfeab62f7051.jpg
#   inflating: Wind Turbine damage/train/20240120_153702_jpg.rf.6bfbbbbb720bf96ec9924998f8ea17e7.jpg
#   inflating: Wind Turbine damage/train/20240120_153706_jpg.rf.b07b90d2f743f3e3499d03246fa1ea7d.jpg
#   inflating: Wind Turbine damage/train/20240120_153721_jpg.rf.05035bcf2a4aca0e8e9b952e628e0e74.jpg
#   inflating: Wind Turbine damage/train/20240120_153727_jpg.rf.f425f61e78175b583f541d6a3493cdb1.jpg
#   inflating: Wind Turbine damage/train/20240120_153745-0-_jpg.rf.fd921869841e470dc3ea37b931c7f56b.jpg
#   inflating: Wind Turbine damage/train/20240120_153745_jpg.rf.b541071d9b09baedd8444a72625d5492.jpg
#   inflating: Wind Turbine damage/train/20240120_153746-1-_jpg.rf.65136b660b2da3ccc3735d4132e18fd0.jpg
#   inflating: Wind Turbine damage/train/20240120_153747-0-_jpg.rf.e1ba082eb6e82e9258a5d7887a8ed937.jpg
#   inflating: Wind Turbine damage/train/20240120_153748_jpg.rf.126e8f9ef1f32f4d0438839b8c83ca1c.jpg
#   inflating: Wind Turbine damage/train/20240120_153749-0-_jpg.rf.9740146bad6ef5a435dfde4d1a676a5a.jpg
#   inflating: Wind Turbine damage/train/20240120_153749-1-_jpg.rf.f2ce079435767ba8ce7dcc4189ad73da.jpg
#   inflating: Wind Turbine damage/train/20240120_153749_jpg.rf.0e93984b939fba82d5977599b207bc07.jpg
#   inflating: Wind Turbine damage/train/20240120_153750_jpg.rf.6958401a7ed423a85b3831db696967e3.jpg
#   inflating: Wind Turbine damage/train/20240120_153755-0-_jpg.rf.21de78e9c093df43dc18436d7315807b.jpg
#   inflating: Wind Turbine damage/train/20240120_153755-1-_jpg.rf.ada437aa17265a8492da60e55313a1c8.jpg
#   inflating: Wind Turbine damage/train/20240120_153755_jpg.rf.9be76f143e05bbd55c2c934d2648ae8c.jpg
#   inflating: Wind Turbine damage/train/20240120_153756-0-_jpg.rf.196332769d6a74791ca1f214f6478115.jpg
#   inflating: Wind Turbine damage/train/20240120_153803_jpg.rf.8824c1ea3a3ae25f363fd4271765399b.jpg
#   inflating: Wind Turbine damage/train/20240120_153804_jpg.rf.7e57e234bfedaa859d2c5aac20edef98.jpg
#   inflating: Wind Turbine damage/train/20240120_153811_jpg.rf.0ceaa485ba4d1e6bcb42f50b77ab3071.jpg
#   inflating: Wind Turbine damage/train/20240120_153826_jpg.rf.5608f89d1562c878fe3d3d61984e410b.jpg
#   inflating: Wind Turbine damage/train/20240120_153829_jpg.rf.c336fb52fe569e9acc67d1df1ae6886a.jpg
#   inflating: Wind Turbine damage/train/20240120_153832_jpg.rf.287b0755a16275d9cca761f5d20a73d9.jpg
#   inflating: Wind Turbine damage/train/20240120_153835_jpg.rf.ab71e34dd740f85ef956fe71f36df9dc.jpg
#   inflating: Wind Turbine damage/train/20240120_153836_jpg.rf.d09d2c48f85fc2d9df1795d7047d662b.jpg
#   inflating: Wind Turbine damage/train/20240120_153842_jpg.rf.3c7f9279aa1f6565c4e21daf02a51054.jpg
#   inflating: Wind Turbine damage/train/20240120_153845_jpg.rf.608cbc8a94082cec421af5ce483e1c45.jpg
#   inflating: Wind Turbine damage/train/20240120_153848_jpg.rf.157d9d432f7744c3078c276f3112260c.jpg
#   inflating: Wind Turbine damage/train/20240120_153850_jpg.rf.6913745dd2161c662f2210683d84a018.jpg
#   inflating: Wind Turbine damage/train/20240120_153859_jpg.rf.21107e5c7dc9b7f40c71e082df6f311f.jpg
#   inflating: Wind Turbine damage/train/20240120_153902_jpg.rf.126ec7ef6ae9db1ab56b1129e2060c08.jpg
#   inflating: Wind Turbine damage/train/20240120_155124_jpg.rf.8aae51c87731e67b306134182440d0bc.jpg
#   inflating: Wind Turbine damage/train/20240120_155142_jpg.rf.b2fa3514041a7c8a223541f7d196e995.jpg
#   inflating: Wind Turbine damage/train/20240120_155143_jpg.rf.f0fa9ddb4fbeb3f765184f021f5faad5.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0004_jpg.rf.d513b63b7298a4a855999d2a3b6c69bf.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0005_jpg.rf.df171385b63a35228af5927e74e25acb.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0006_jpg.rf.4be7c5ebfc479c7a6926f3e9d8f6c386.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0007_jpg.rf.09535572ffb20df4199c3f873f9072ef.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0008_jpg.rf.0a8b3f1aeefc36d75f24525333c731d7.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0009_jpg.rf.1cfc33fd3263ff5477d042d198587511.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0013_jpg.rf.ba8715c79a55bd66bfc8caa85094e995.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0016_jpg.rf.d3ded2f252e14baba60156d0f6ef1148.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0017_jpg.rf.3fb17434499e9abc3e23a5b7c3d04a39.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0018_jpg.rf.c3d6e5a68fce648e758b8446dae38f92.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0019_jpg.rf.25df8be26c7b709f5ae5c96c7b1b0ae7.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0021_jpg.rf.c1d4d18a5494501d3737cdf1f84a0864.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0022_jpg.rf.e31368e7a8bf6f1bf8eff68b80dd705b.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0025_jpg.rf.336a6465a05685a735be21cf3cc126d8.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0026_jpg.rf.eee7044c08b21d7a14c39e0ffff8ba2b.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0027_jpg.rf.f6fb1cb8977df7e8b28acad004fdff82.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0028_jpg.rf.3f2af1eb164f2fd318f0c02c4162e121.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0029_jpg.rf.eff617eef511884356a3411a97e36552.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0030_jpg.rf.88657600b63056b4aee3331c135dde76.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0031_jpg.rf.8baa7d3cb861e140fa2a8e38d0daeffd.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0032_jpg.rf.2ea9259c4ef7dfee1574eed34d3934bc.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0035_jpg.rf.59de59ac71ec680a4763ee1d0f2f6b47.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0036_jpg.rf.940d083215f7417fe63f66bb0f7024f3.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0037_jpg.rf.a0a2853a8e83c0479f5ae2517b3f25de.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0038_jpg.rf.7c47af8fac53cce06aeddeffacfbd2bc.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0039_jpg.rf.f9a2e23ff8a54a536ff7c963b1887de5.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0040_jpg.rf.1f9179ea7e7aa8dd1993c4576573075b.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0041_jpg.rf.0e90d76b5f474a6e658752ada155ba42.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0042_jpg.rf.64ea1c21ba8c91b4e4e64653b52e48c5.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0043_jpg.rf.4eac95a39f392fc6a5381bdf8947a6fb.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0044_jpg.rf.0cb38eaaba0a70f2264ea01e5a916c4a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0045_jpg.rf.56e3bcec40088e54333f7f0dca2d2a21.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0046_jpg.rf.15c3b99cbbacef4c0011fcc50a7fc8b6.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0049_jpg.rf.e6da8ff9838c0f56f5ef38946e2675e1.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0050_jpg.rf.e96d5dcf351925a01616e0ae652f6e10.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0051_jpg.rf.5f293e551fd7fb83188b12c6504f8c2a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0053_jpg.rf.98318830108d68666fc5a58400318aca.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0054_jpg.rf.8e515aed05cee00e85ae18ef8383e80a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0055_jpg.rf.9095c1ba216e2ab3b69c0509feaba035.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0057_jpg.rf.7b1e518b55e078ab4d8b76dbc150b88a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0058_jpg.rf.9c4e0c0b55635df3e5bff54a1d920354.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0059_jpg.rf.7093260ec7018213902773c2cc75ffb9.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0060_jpg.rf.a874120b8526b3fb736e7d853f226301.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0062_jpg.rf.196700764ce941132c44055e7cd7e8a9.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0063_jpg.rf.1817e775fe3a435a319a85cf471ee82d.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0064_jpg.rf.ee9d26248cf6baee8afed4669a33e9db.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0065_jpg.rf.872a73f11f18d0581585fbbe2d9e5b48.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0066_jpg.rf.9c401b0f3cb4c520ef9dfbd17f2ac16e.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0067_jpg.rf.7ba6f3e6630ec0e5563907f5eec7bf78.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0068_jpg.rf.ae457d97a5fba7887ed3db81a40c5679.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0069_jpg.rf.5816fb6375b85fd85521ab7a2ed396bf.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0070_jpg.rf.2116f228aff1de2056bad299b2e205e8.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0071_jpg.rf.fd3a45bbe13a1d3ce8b3e3c861e631ae.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0072_jpg.rf.6f524d0766e730f5438bfc034f1834b9.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0073_jpg.rf.d4165a1b1580c4895cce6a8abcc81adf.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0074_jpg.rf.089f65d74d92a8fad91e31e7e56e4975.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0076_jpg.rf.e70c45c05a24f8bceeff9f8c4886aca9.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0078_jpg.rf.c17e372df12308f79588b5c4bdf37055.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0085_jpg.rf.99a7407c179f27ad02d5d1eb9ff87144.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0087_jpg.rf.6424e9a4d44fc7c170b53296de1b6880.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0089_jpg.rf.d0d4e48d70d2b8144af8c4dc707d62db.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0091_jpg.rf.253305a26d655468d7ccdf7f357529a2.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0092_jpg.rf.3d902d08081341e1ad3abb7081d9ccbd.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0093_jpg.rf.a47746ea1014beddc36384f62e55197d.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0094_jpg.rf.9c0780877f285e91636fa30fc4e20f1d.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0096_jpg.rf.5c95978d5e6ed9a1137c7c4a2b26f4d1.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0097_jpg.rf.d26ab4cd4c323b0699ab9f268324ad84.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0098_jpg.rf.b7acd75be76f0afcf645d229f21ee72e.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0099_jpg.rf.7743ace20ae348ea1141fd6c2058ceb2.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0101_jpg.rf.b4e4d0281f789db4a5a8eec2cc1d1423.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0102_jpg.rf.9503129f9d885eb9b87f0b1c13c09353.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0103_jpg.rf.d41e819c688875753a5d7b454a8c826e.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0104_jpg.rf.b806f3d3a74d9393efa0baab046c8202.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0105_jpg.rf.83aeb637357f93b0908ebdf9dd00c55b.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0106_jpg.rf.c1d96f96bd0036d6c8d4ddf8c84d50b8.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0108_jpg.rf.1894778de7f45d60ec3b83af57999a99.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0109_jpg.rf.72dc5bb33fb3769c788419bc553393be.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0111_jpg.rf.7c2cb99e266a9c02086290d2cd534cdf.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0112_jpg.rf.8f8e43cd640ca649bd8ef7e6718e9771.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0114_jpg.rf.0fb15d13f8e3ad318d0dee50f5c02a6e.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0115_jpg.rf.f389686579f432059d4a053dc8f2125c.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0116_jpg.rf.00b312e13ce02ebb4d4bc95f0ee403b2.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0117_jpg.rf.282dd6565e6df2062470807e25a57cc4.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0118_jpg.rf.e4227d8ab29a8df6c3386999c8fd7372.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0119_jpg.rf.f223d438886a4c462f1d46236872ad21.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0120_jpg.rf.02be8d0fdaf864c3fcb637aee16e36be.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0121_jpg.rf.8aa7f0ca3493176b356f190d9034315f.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0123_jpg.rf.46782dab431e8912df59b197188f6346.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0124_jpg.rf.1ffb916bf6b583af6b398b748acebed8.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0125_jpg.rf.0d187816ce2099cf74aba48799f74a11.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0127_jpg.rf.5da516e20863ac7ce6a52c2a8e25d1c8.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0128_jpg.rf.6f2c1020f7f6d623b7f293e3c10a392c.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0129_jpg.rf.9e41e123e850dfef885b6a25cecc8ecf.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0130_jpg.rf.dbde1688f572290e7fc0582a0c69b19f.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0131_jpg.rf.b4e825a2d3d6a7f6c48d3ab52b863409.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0132_jpg.rf.edeaba7803b80e09b81588a903d808de.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0133_jpg.rf.615ca3f291bece1d8e35a2e8c2b2687d.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0135_jpg.rf.87b8122e6fdab4fb60b3d741838d1612.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0136_jpg.rf.8349def86450427da1c001bbdf1bb435.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0137_jpg.rf.ba4cc400fbf5c35317765f48c97e0809.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0139_jpg.rf.ed5376e5806d4b2b69da41cbe4786a1c.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0140_jpg.rf.eab764984364aea5457ffd028a03765b.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0141_jpg.rf.5409f8824344d4820d6907d9adfc89dc.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0142_jpg.rf.108e64c1b0cfc45a43bd3702dfed24aa.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0145_jpg.rf.c6c92935240ddfeac3b629af35e85e28.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0146_jpg.rf.f818366b1a2748f42a2452390ea4336a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0147_jpg.rf.10d6cfa70053769a62eecde1208e0ab2.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0148_jpg.rf.37d1333f08aa7048e27112883ffd98fc.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0150_jpg.rf.4c08c95e8fecf50947aaea34f74226b6.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0151_jpg.rf.76c83b692ad65ba73a3a6c8c2ab7ad98.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0152_jpg.rf.1c4316eb21cba62df1b1a384e216f331.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0153_jpg.rf.6dbf9440142e9de2fc15bc6b82945974.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0154_jpg.rf.b833bca37605e60d4b5a183b4b408cda.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0156_jpg.rf.050a2c8b411b869b28d68e1a3e98b59b.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0157_jpg.rf.21f1c16603db093828e77e6cbed4c18c.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0158_jpg.rf.dd119fb1e8874ea8fe3df4f76caccd71.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0159_jpg.rf.1aa64ce4e5a50fdd3a2bd20a72d75d8a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0163_jpg.rf.e89ea7047c3946f934e5c4ee6a560874.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0165_jpg.rf.6e3c1ec45b558f9eb329a8f57cc735fd.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0166_jpg.rf.cf6ad62c698c3f91fce5cf58944f96e3.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0170_jpg.rf.75b693192a12f53b8b6175041e7a2073.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0171_jpg.rf.0913f0160c5cf5e58653963e5bd4a910.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0172_jpg.rf.05bf710a66f666dcac5961d31bd4f881.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0175_jpg.rf.260126a74666fe8b1ea285985dd4b373.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0176_jpg.rf.1986586d101c36640277ede7a593c0e7.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0177_jpg.rf.1d0fb435b5b0c84f6c288504452e1a7a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0178_jpg.rf.1a76d535f5b7a385000a4d0ea6d23050.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0182_jpg.rf.c17fbf890b136bc753da7d28669d4589.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0183_jpg.rf.6f8fad299ce7e36110531f11c04675ba.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0184_jpg.rf.e271ddf7de7a02e1f47f9abdbf3b31ad.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0185_jpg.rf.fa42f94b04e9a4068104891e418949ba.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0186_jpg.rf.369ce9740a4753efa705474efa405f00.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0187_jpg.rf.957cff4de7fcac79b130201c6e4f2375.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0188_jpg.rf.3c12388c88d2d7d418a4cdb991af900b.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0189_jpg.rf.f77703f4ad8a8b67e5a4534793eda05e.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0192_jpg.rf.c03d01454e98679203ca4fb4ed8b05cb.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0196_jpg.rf.ec508f2da4bf4a1e5839ec66be2f50ce.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0198_jpg.rf.302528e85e9b0583a79b8bb48bfbc2a0.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0199_jpg.rf.cf13fcca0e8e1fd96b9647d3086178e6.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0200_jpg.rf.428d949fbe46ae7435e4ce2c9f151fd1.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0201_jpg.rf.5f8ff6c0a96676662aed66ed2ede73c0.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0205_jpg.rf.18af10fb5ddde160f6d64dd87b41b17e.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0207_jpg.rf.0f9fb27ae47a58c650b9ff6b9592fbbc.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0208_jpg.rf.f7a2635c9aae2c16f378383a1c969b5d.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0209_jpg.rf.22b48f02c14d341c0e3cf1829e39baaf.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0210_jpg.rf.699873378e4a1b13cb0b3a6072435359.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0211_jpg.rf.d7697e8cc2b5ca1d69e7d00e16043377.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0213_jpg.rf.3f263dc0da2a5ae57494f8d977b901ca.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0215_jpg.rf.bcaf14a2dfbff467af0b6cc3bf021e52.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0216_jpg.rf.606eddabc98ba2373495594794112cf3.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0217_jpg.rf.dbd22a9c4779fde234e9c09ffa851eb2.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0218_jpg.rf.ecb78685c34a161e6de6d2f3c229fb7a.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0219_jpg.rf.7023a7a8ba5ad7077f39a9318e2d57a3.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0220_jpg.rf.5a268f6230ff8eb1226cbbd39346bae5.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0221_jpg.rf.3f0ef4b21cd46ba3d8dcf977aeb286d7.jpg
#   inflating: Wind Turbine damage/train/20240120_155211_mp4-0223_jpg.rf.612032322e3dd88290e2d2f0d12619d6.jpg
#   inflating: Wind Turbine damage/train/20240120_160452_jpg.rf.f07a1a0561dae48a9c50b7b25aaaba6f.jpg
#   inflating: Wind Turbine damage/train/20240120_160453_jpg.rf.06cd8e2d89256b06c050e57efda81726.jpg
#   inflating: Wind Turbine damage/train/20240120_160454_jpg.rf.48a3257ecaf549cf9699b65161630945.jpg
#   inflating: Wind Turbine damage/train/20240120_160455_jpg.rf.a8a39b21db610bd90f764a66625dfce9.jpg
#   inflating: Wind Turbine damage/train/20240120_160456_jpg.rf.7ca953cfa41924992c008ac9437e05f0.jpg
#   inflating: Wind Turbine damage/train/20240120_160458_jpg.rf.25d4e1972a9fb79c9f53dfcde137ec9f.jpg
#   inflating: Wind Turbine damage/train/20240120_160511-0-_jpg.rf.74e9afcde502508daf4990bdaff4635c.jpg
#   inflating: Wind Turbine damage/train/20240120_160511_jpg.rf.95aac76d9b69745063da8f7a05e81c18.jpg
#   inflating: Wind Turbine damage/train/20240120_160522_jpg.rf.8d0f37fe464cd173deee518b636e3c8f.jpg
#   inflating: Wind Turbine damage/train/20240120_160527_jpg.rf.9af78c502af65fe00d55258bf8f39b85.jpg
#   inflating: Wind Turbine damage/train/20240120_160528_jpg.rf.fd49019f5aa171e00305aadbcf3c3122.jpg
#   inflating: Wind Turbine damage/train/20240120_160531_jpg.rf.e6e904fec574ceaeefa10c1b89f1a6d6.jpg
#   inflating: Wind Turbine damage/train/20240120_160540_jpg.rf.b180576783adbf024b8df4a663630a3f.jpg
#   inflating: Wind Turbine damage/train/20240120_160543_jpg.rf.91e44075807651170be6cb5d90f9d795.jpg
#   inflating: Wind Turbine damage/train/20240120_160559_jpg.rf.b54a3eff3926a23305a56d6759a07c7c.jpg
#   inflating: Wind Turbine damage/train/20240120_160602_jpg.rf.66fb47fc241e3e9d58459f351cd3d2ff.jpg
#   inflating: Wind Turbine damage/train/20240120_160603_jpg.rf.71568ddd1c7786d1869bedd018fe4f18.jpg
#   inflating: Wind Turbine damage/train/20240120_160605_jpg.rf.cb8606ca0e21cf10a9b33504df5f5d02.jpg
#   inflating: Wind Turbine damage/train/20240120_160606_jpg.rf.b36c8731aa8ead45ed18fdadf3237f64.jpg
#   inflating: Wind Turbine damage/train/20240120_160615_jpg.rf.6bfd5fcd5110bc6469e30e856e95225d.jpg
#   inflating: Wind Turbine damage/train/20240120_160617_jpg.rf.08285f48d2d38cc7e41ad40e3d0f651b.jpg
#   inflating: Wind Turbine damage/train/20240120_160618_jpg.rf.690eb92b8f10852d88f72a46a0da96de.jpg
#   inflating: Wind Turbine damage/train/20240120_160619-0-_jpg.rf.2f22e8d4d17f91c7107f43dfb6ba1694.jpg
#   inflating: Wind Turbine damage/train/20240120_160619_jpg.rf.1059071c601c5b7139185b8d2fff6ce0.jpg
#   inflating: Wind Turbine damage/train/20240120_160620-0-_jpg.rf.9db3175f402f368179cef6409f0f7ebe.jpg
#   inflating: Wind Turbine damage/train/20240120_160621_jpg.rf.a1c6edc725cbe9bcf9a7f3a0b23a5185.jpg
#   inflating: Wind Turbine damage/train/20240120_160622-0-_jpg.rf.ff7e3649d006f88a298c1537b879a6ed.jpg
#   inflating: Wind Turbine damage/train/20240120_160623_jpg.rf.2405be2220c46fa0946df1a588bf06ac.jpg
#   inflating: Wind Turbine damage/train/20240120_160633_jpg.rf.eda5afbee418f9aa04765beaccfb9038.jpg
#   inflating: Wind Turbine damage/train/20240120_160707-0-_jpg.rf.91cb949c9eeb9ee551fedeec29111502.jpg
#   inflating: Wind Turbine damage/train/20240120_160707-1-_jpg.rf.b4dc4fbec89e2cfeac8ffb8043aaa023.jpg
#   inflating: Wind Turbine damage/train/20240120_161015-0-_jpg.rf.65b3b8fd9d1cb6eb655960bbed99728c.jpg
#   inflating: Wind Turbine damage/train/20240120_161015_jpg.rf.6d12f4252991d3efba92208570154306.jpg
#   inflating: Wind Turbine damage/train/20240120_161016-0-_jpg.rf.05cab211d0a42732a85bcef245c19076.jpg
#   inflating: Wind Turbine damage/train/20240120_161016-1-_jpg.rf.2864e9a940897cc0fe8053918a11b8d4.jpg
#   inflating: Wind Turbine damage/train/20240120_161016_jpg.rf.56f18f0bca61b59b625ea999bad0d7e9.jpg
#   inflating: Wind Turbine damage/train/20240120_161017-0-_jpg.rf.b687f5ef4ce72498babbe84b93e66a5c.jpg
#   inflating: Wind Turbine damage/train/20240120_161020_jpg.rf.edae38671c554f4a659da9c3f7a1a5d3.jpg
#   inflating: Wind Turbine damage/train/20240120_161022_jpg.rf.57c04e9280b2f1dcb6bc2c9a9d87898c.jpg
#   inflating: Wind Turbine damage/train/20240120_161029_jpg.rf.ccdb37c7f3c999cf3286ec9628eee15f.jpg
#   inflating: Wind Turbine damage/train/20240120_161030-0-_jpg.rf.b43920ce20dcde1e698bac64d1a9233a.jpg
#   inflating: Wind Turbine damage/train/20240120_161030_jpg.rf.d3aa5258cb49b2459581ebe09b008c8d.jpg
#   inflating: Wind Turbine damage/train/20240120_161031_jpg.rf.764ac7b346b8670c6230297d09678f68.jpg
#   inflating: Wind Turbine damage/train/20240120_161043_jpg.rf.351ebdfea2283d3e3b03e825e32465d8.jpg
#   inflating: Wind Turbine damage/train/20240120_161048_jpg.rf.504cf47cebbca96f90ac67930eb57fe0.jpg
#   inflating: Wind Turbine damage/train/20240120_161049_jpg.rf.bd10789bb7da03d017aafff60549c7cf.jpg
#   inflating: Wind Turbine damage/train/20240120_161050_jpg.rf.b9dfa5cdebbdde964cd93774af3a40b7.jpg
#   inflating: Wind Turbine damage/train/20240120_161051_jpg.rf.e9a7a13684394752afd499c6dae88420.jpg
#   inflating: Wind Turbine damage/train/20240120_161054_jpg.rf.764fd9afe854e1bc4c32dc4c8de1416a.jpg
#   inflating: Wind Turbine damage/train/20240120_161100_jpg.rf.cf0895d70a76e9aac656512f1ea2398f.jpg
#   inflating: Wind Turbine damage/train/20240120_161101_jpg.rf.618dc8e4c83e80346f079230b2093ca8.jpg
#   inflating: Wind Turbine damage/train/20240120_161103_jpg.rf.0ed457d18165968656bb813ca66fc108.jpg
#   inflating: Wind Turbine damage/train/20240120_161104_jpg.rf.6504902ae1984d8e8fe2a5283b8abc4e.jpg
#   inflating: Wind Turbine damage/train/20240120_161105_jpg.rf.0fe2db4c1e33c806afbda4baf1e306e5.jpg
#   inflating: Wind Turbine damage/train/20240120_161107_jpg.rf.dbe8ffc59618aa05cc6733f6b2787e50.jpg
#   inflating: Wind Turbine damage/train/20240120_161117-0-_jpg.rf.2ba5e6516894f3f9ec00e43aed8d404d.jpg
#   inflating: Wind Turbine damage/train/20240120_161117_jpg.rf.64eff5e80e1defdec2710d3f5f2e7fe0.jpg
#   inflating: Wind Turbine damage/train/20240120_161121-0-_jpg.rf.02bbe4960b80010327a80570a28fa55d.jpg
#   inflating: Wind Turbine damage/train/20240120_161121_jpg.rf.56c6da0c553361e9227253fdac09ee46.jpg
#   inflating: Wind Turbine damage/train/20240120_161122_jpg.rf.5238e810eece5632a9b6f49db3c94381.jpg
#   inflating: Wind Turbine damage/train/20240120_161123_jpg.rf.cb5c41c2f4f19f809a410f57822f6cbb.jpg
#   inflating: Wind Turbine damage/train/20240120_161124-0-_jpg.rf.9770cece27561acb7297e693c30d64f3.jpg
#   inflating: Wind Turbine damage/train/20240120_161124-1-_jpg.rf.1b7b85fd933cc37f29e40f24832e7dbe.jpg
#   inflating: Wind Turbine damage/train/20240120_161124_jpg.rf.a7139f8049f5b8f252db6e887f3d3059.jpg
#   inflating: Wind Turbine damage/train/20240120_161125-0-_jpg.rf.175dc7c976f54ddcd6bf59d1837b1945.jpg
#   inflating: Wind Turbine damage/train/20240120_161125_jpg.rf.06ae851ec2416fe4d8219e0d282cc0ec.jpg
#   inflating: Wind Turbine damage/train/20240120_161126-0-_jpg.rf.829928257c3cc4ddb009f0a26b96114e.jpg
#   inflating: Wind Turbine damage/train/20240120_161127-0-_jpg.rf.9db34559cd4e5888d07b01449751a79d.jpg
#   inflating: Wind Turbine damage/train/20240120_161127_jpg.rf.715531baaa5a22071d9abbc1abd0dab2.jpg
#   inflating: Wind Turbine damage/train/20240120_161128-0-_jpg.rf.f14ccb2ab02a66b27bda37c940c7a611.jpg
#   inflating: Wind Turbine damage/train/20240120_161128_jpg.rf.ae9158aea9c458fcf3bfd4bf5811478f.jpg
#   inflating: Wind Turbine damage/train/20240120_161129-0-_jpg.rf.fcd134469c5cd792be8fa4f650688507.jpg
#   inflating: Wind Turbine damage/train/20240120_161129-1-_jpg.rf.58719ad0672509dafbc89616c2da9323.jpg
#   inflating: Wind Turbine damage/train/20240120_161129_jpg.rf.170839b8976422ee8a55764835347052.jpg
#   inflating: Wind Turbine damage/train/20240120_161130-1-_jpg.rf.46f139e6dfe7bd5beb79ce46fcb9ad82.jpg
#   inflating: Wind Turbine damage/train/20240120_161130_jpg.rf.294beceb0b5493df04b4360b4d34a7f4.jpg
#   inflating: Wind Turbine damage/train/20240120_161131-0-_jpg.rf.a57024b82fe96244c2e6a05c332bfad8.jpg
#   inflating: Wind Turbine damage/train/20240120_161131-1-_jpg.rf.e94783208f15adfb394f2620cbc69f43.jpg
#   inflating: Wind Turbine damage/train/20240120_161131_jpg.rf.a51064c0365ce9bb57753370abcb0f2a.jpg
#   inflating: Wind Turbine damage/train/20240120_161132-0-_jpg.rf.f6c652d0dde1fb92c0d27fd363dce62a.jpg
#   inflating: Wind Turbine damage/train/20240120_161132_jpg.rf.16a357f2ba96a0fc4599d213af9f6272.jpg
#   inflating: Wind Turbine damage/train/20240120_161134_jpg.rf.d84860c03a0b8b60e521804e3af35896.jpg
#   inflating: Wind Turbine damage/train/20240120_161135-0-_jpg.rf.a6a5a6fdc7a1ac5fff8ecf49fb08c50f.jpg
#   inflating: Wind Turbine damage/train/20240120_161135_jpg.rf.a4104c0c9b632b93d84021feb5b3fb09.jpg
#   inflating: Wind Turbine damage/train/20240120_161145_jpg.rf.a5a1b05c6f3367389c413e5b137e94ed.jpg
#   inflating: Wind Turbine damage/train/20240120_161206_jpg.rf.c97529c66d171a1af596f728bb7c29fa.jpg
#   inflating: Wind Turbine damage/train/20240120_161222-0-_jpg.rf.845dbaeaeb44b1ca02e6d484181628ce.jpg
#   inflating: Wind Turbine damage/train/20240120_161222_jpg.rf.5590a518aedf7aea1822c3610a58dad7.jpg
#   inflating: Wind Turbine damage/train/20240120_161223-0-_jpg.rf.2e0cba3874f7eae9862c13718086480f.jpg
# ...
#   inflating: Wind Turbine damage/valid/20240120_163008-0-_jpg.rf.3428f9c99fce7b4a6206dffdc3e784a6.jpg
#   inflating: Wind Turbine damage/valid/20240120_163034_jpg.rf.9110c8c3b9d824b6a61ffd938cc6d320.jpg
#   inflating: Wind Turbine damage/valid/20240120_163039-0-_jpg.rf.2af0dcc7d90baff7e21d1435137a8f53.jpg
#   inflating: Wind Turbine damage/valid/20240120_163039-1-_jpg.rf.6b7ab27cb6067911201adc226bceeede.jpg
#   inflating: Wind Turbine damage/valid/20240120_163041-0-_jpg.rf.a4c251293e0e80648881ab122c9aff47.jpg
#   inflating: Wind Turbine damage/valid/20240120_163041-1-_jpg.rf.a2c1b28bb58d23e9627f69c80a757866.jpg
#   inflating: Wind Turbine damage/valid/20240120_163041_jpg.rf.2f3de69615dc8407e6264e9859ad979b.jpg
#   inflating: Wind Turbine damage/valid/20240120_163042-1-_jpg.rf.40118f6846b294fe26a87de5ec7a40e5.jpg
#   inflating: Wind Turbine damage/valid/20240120_163042_jpg.rf.4a74ce891920881624e5e3e84773a92d.jpg
#   inflating: Wind Turbine damage/valid/20240120_163044-0-_jpg.rf.9cb08c9791c7b396dea6b49240738872.jpg
#   inflating: Wind Turbine damage/valid/20240120_163047-0-_jpg.rf.1ab3e45df70452b86080301c4eb375c0.jpg
#   inflating: Wind Turbine damage/valid/20240120_163048-1-_jpg.rf.bab23497780ee9e163046f4de7e63711.jpg
#   inflating: Wind Turbine damage/valid/20240120_163049_jpg.rf.bc30b3b4a1c8e63fd4d244b7661cbd5a.jpg
#   inflating: Wind Turbine damage/valid/20240120_163052-0-_jpg.rf.6e33d3ec854c5e1248a43e72940d8943.jpg
#   inflating: Wind Turbine damage/valid/20240120_163052-1-_jpg.rf.dcbacd3b7ca87985ed56084759bd785b.jpg
#   inflating: Wind Turbine damage/valid/20240120_163053-0-_jpg.rf.f7e43dc1361807803d2e5dfe037ae93c.jpg
#   inflating: Wind Turbine damage/valid/20240120_163054-1-_jpg.rf.39c78614d18582ba73e29309cded2b24.jpg
#   inflating: Wind Turbine damage/valid/20240120_163642-1-_jpg.rf.72ffbce4d6fe8e2d545f66e64b6223eb.jpg
#   inflating: Wind Turbine damage/valid/20240120_163645-2-_jpg.rf.21115c8e596ce289b1425098a2ad6ab3.jpg
#   inflating: Wind Turbine damage/valid/20240120_163648_jpg.rf.1bf873f0fcfb274a41a2d89c78c250d4.jpg
#   inflating: Wind Turbine damage/valid/20240120_163649-0-_jpg.rf.db0b662db4cac943e985a7dd2f9cc6dc.jpg
#   inflating: Wind Turbine damage/valid/20240120_163651_jpg.rf.d397b36f7ab187e79932720b7d9a5201.jpg
#   inflating: Wind Turbine damage/valid/20240120_163723-0-_jpg.rf.b764b5145b91bcc084f7a124b29f1d20.jpg
#   inflating: Wind Turbine damage/valid/20240120_163724-0-_jpg.rf.17b03e45cb00eec4820558a9c335e712.jpg
#   inflating: Wind Turbine damage/valid/20240120_163730_jpg.rf.fc479b72d1ec281f8815e95f3b9c443d.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-1302_jpg.rf.a4edb6cf2d06caf25bd26eb51eee11e2.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-1310_jpg.rf.eb8ecc70304734e3722cab811f3093ed.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-1352_jpg.rf.d6537d4657165bd1a50a49300b6420b7.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2234_jpg.rf.c86f81fda75a652b2c7ac69ff457816b.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2236_jpg.rf.1ded21f80cdf358e12499fc2fe8710d2.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2242_jpg.rf.81a165c3b0ea9ae9248837e4ae614e66.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2244_jpg.rf.c1fe2ef90aa231348e3560c8a6df8f6d.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2250_jpg.rf.c1f1b5d457342278591602971b070037.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2266_jpg.rf.4360fc44fcd2e8f90fe2da30b5391f3e.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2272_jpg.rf.fa6aa061f66608150ede36daa0165d29.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-2290_jpg.rf.ada2a748b396a171d8177ecc02a9e521.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4068_jpg.rf.59426cc28239372a6a77a7f18303b018.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4088_jpg.rf.dffb30ed9ae49faf5af0a0f433d41d97.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4092_jpg.rf.b16922937cabc39b67568354622e1312.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4096_jpg.rf.e3834c9a654c2cd673f78b397bbdec09.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4104_jpg.rf.15540b19e1fff32c471bd37b987da159.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4116_jpg.rf.0bb1fbc90ad7624ca21b084feb4f525e.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4118_jpg.rf.d34c89c80bf53f8356ac9e5cb621235d.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4124_jpg.rf.90fc866263e09a814410dc790c4afb31.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4126_jpg.rf.9cbb2f5eb93abf3ea54a50379bea4d35.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4132_jpg.rf.8624e526585c2a63e8b52177e9962428.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4134_jpg.rf.d9a7ae245f7bbcfa743a27d48472f6e1.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4138_jpg.rf.e1a2022c1fee5fc467bdd93ad64d1694.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4152_jpg.rf.c260e35df86201ac2e2354f4866ba2c8.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4154_jpg.rf.f9bdf2342e137948a63c94d928e93760.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4156_jpg.rf.aa0d55f4d887bc9ee12a69a9e7717c85.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4158_jpg.rf.3863350287d9755f670783cc05736627.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4166_jpg.rf.47a821aacaed5aa43f02cccec3430781.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4172_jpg.rf.37683c9adbc835d193ca4688f048fcc8.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4180_jpg.rf.5d4da805499fd7422e89833334feb73d.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4182_jpg.rf.7e48417b47d1c249e5c81f328a51a319.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4194_jpg.rf.fff4f7f4e753c5822dc6ba517c67df42.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4202_jpg.rf.fb056aef9552d10e33cc9a81d6e3ddbb.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4676_jpg.rf.c1653eb090496803a52ccc46cbccf42e.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4686_jpg.rf.82da8d17fa99145952bbdf9d34d68727.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4688_jpg.rf.6e1239d25606beff8165cad0702f906a.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4692_jpg.rf.3ab30d80c1cc60170411085e457e0502.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4694_jpg.rf.de79bf372283829ec114e6e02429b48e.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4696_jpg.rf.cec2e4c82d42590381dc7d69d25ff0cc.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4698_jpg.rf.bcf3d57ceb23e926f751aff13f6b341c.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4702_jpg.rf.4fa6fbeeae60969ee198fddc0d3d3a0b.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4704_jpg.rf.6accadb7d7f98560493e3e278da61f05.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4708_jpg.rf.354ab57a005eaa0ac561579a685ae293.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4712_jpg.rf.b322b51b1ed9428f0be59efd00f56573.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4722_jpg.rf.ca40a6bd04e7d0a50ebbc618bfc0d7a3.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4744_jpg.rf.caacad8a9bf11ecbe278f0f76cabd186.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4750_jpg.rf.b47859c3c705b78b253b8c667e4fbd2a.jpg
#   inflating: Wind Turbine damage/valid/20240120_164348_mp4-4789_jpg.rf.8ba6808b338295d24f852387a09dca50.jpg
#   inflating: Wind Turbine damage/valid/DJI_0004_JPG.rf.fd18b499862ccac0d59d242b186c1184.jpg
#   inflating: Wind Turbine damage/valid/DJI_0012_JPG.rf.47446474d7409074084b68da4cf9fd28.jpg
#   inflating: Wind Turbine damage/valid/DJI_0034_JPG.rf.afad2e63a2d68a3999464dcb26ded149.jpg
#   inflating: Wind Turbine damage/valid/DJI_0035_JPG.rf.488d4d7167aeb80db22da12f06a74661.jpg
#   inflating: Wind Turbine damage/valid/DJI_0036_JPG.rf.811dba001274da9c3514027d7046f1cc.jpg
#   inflating: Wind Turbine damage/valid/DJI_0052_JPG.rf.9e2425e78277e9172c8158cd0eb122e6.jpg
#   inflating: Wind Turbine damage/valid/DJI_0053_JPG.rf.4705b517a28be02894bb3e24ce1a37ed.jpg
#   inflating: Wind Turbine damage/valid/DJI_0057_JPG.rf.3e8929309a05ee5896852970ae79e086.jpg
#   inflating: Wind Turbine damage/valid/DJI_0059_JPG.rf.ed7dff74866ccf81561a2131e402f5be.jpg
#   inflating: Wind Turbine damage/valid/DJI_0093_JPG.rf.2fae7b10f12728f6ede80be5a625e884.jpg
#   inflating: Wind Turbine damage/valid/DJI_0097_JPG.rf.ea0e13db023bd949dfdde17d0b52f1cd.jpg
#   inflating: Wind Turbine damage/valid/DJI_0129_JPG.rf.b55a922c27df67b65d0cf39ff76234c2.jpg
#   inflating: Wind Turbine damage/valid/DJI_0134_JPG.rf.b4854c283de8a99b67a6bc4d3ad848d5.jpg
#   inflating: Wind Turbine damage/valid/DJI_0160_JPG.rf.409f4902bed52102203ae770d857dbe8.jpg
#   inflating: Wind Turbine damage/valid/DJI_0164_JPG.rf.7c88babd7d22857e090acc8b63d71fae.jpg
#   inflating: Wind Turbine damage/valid/DJI_0167_JPG.rf.bedb7909498e3ce33d02933ea9b4a6a3.jpg
#   inflating: Wind Turbine damage/valid/DJI_0179_JPG.rf.c29b895d041efb08b1eb276dca9e2754.jpg
#   inflating: Wind Turbine damage/valid/DJI_0182_JPG.rf.dfc9b9a39194d30b50e8095e617029bd.jpg
#   inflating: Wind Turbine damage/valid/DJI_0209_JPG.rf.58d9e84f8bb5774630d40df384609429.jpg
#   inflating: Wind Turbine damage/valid/DJI_0216_JPG.rf.52eb453b22d4a21e2a44cfa96f91a0da.jpg
#   inflating: Wind Turbine damage/valid/DJI_0226_JPG.rf.d0ff2bd696e70b5f06ab9fffa9f0ecdb.jpg
#   inflating: Wind Turbine damage/valid/DJI_0334_JPG.rf.6d62adea85574abb8c3c869057b56999.jpg
#   inflating: Wind Turbine damage/valid/DJI_0336_JPG.rf.3fe4b9b8e3b79bbddc53dd83354339ab.jpg
#   inflating: Wind Turbine damage/valid/DJI_0340_JPG.rf.def4492496c30c2e57b17c81be0d4b8a.jpg
#   inflating: Wind Turbine damage/valid/DJI_0361_JPG.rf.04006ca3afa3af642d4fd385c1a073c9.jpg
#   inflating: Wind Turbine damage/valid/DJI_0368_JPG.rf.ad7b4d29c3ba9dfa42a654ed8cb79030.jpg
#   inflating: Wind Turbine damage/valid/DJI_0369_JPG.rf.61a49a975a21568206ca060fe98a7d02.jpg
#   inflating: Wind Turbine damage/valid/DJI_0377_JPG.rf.cf6549f9b8bef6564ffa78c858f4061c.jpg
#   inflating: Wind Turbine damage/valid/DJI_0391_JPG.rf.d334ba324a5148c8b2a4404adf6c05f7.jpg
#   inflating: Wind Turbine damage/valid/DJI_0407_JPG.rf.9f90779e5fa085d2d9bb0222b087b1cf.jpg
#   inflating: Wind Turbine damage/valid/DJI_0415_JPG.rf.1ea5005e7ba6581dd18f976860437283.jpg
#   inflating: Wind Turbine damage/valid/DJI_0426_JPG.rf.1f82f5d0324fb2e9ca0c5108ed923b9f.jpg
#   inflating: Wind Turbine damage/valid/DJI_0438_JPG.rf.a55caf47dae143fbf9e348653510b5ef.jpg
#   inflating: Wind Turbine damage/valid/DJI_0442_JPG.rf.7340953cc13eaf7cb7f963e95dd00d7d.jpg
#   inflating: Wind Turbine damage/valid/DJI_0445_JPG.rf.436390816b2d4c1d9d5c0fc4ef19a086.jpg
#   inflating: Wind Turbine damage/valid/DJI_0448_JPG.rf.001a6437f0317bd79124c86bddf19905.jpg
#   inflating: Wind Turbine damage/valid/DJI_0590-1-_JPG.rf.42c47ab1d9f905f4acbf1310fba9074d.jpg
#   inflating: Wind Turbine damage/valid/DJI_0595-1-_JPG.rf.15e1fb2782f763035d2dcd60204eec57.jpg
#   inflating: Wind Turbine damage/valid/DJI_0596-1-_JPG.rf.f63528a2865e07a53ca170dc5d4cbdc7.jpg
#   inflating: Wind Turbine damage/valid/DJI_0599-1-_JPG.rf.448ec972754585df6fa698c7ee4c9c37.jpg
#   inflating: Wind Turbine damage/valid/DJI_0603-1-_JPG.rf.b0c8ca6e3dff140f0fa5b3178d27eb07.jpg
#   inflating: Wind Turbine damage/valid/DJI_0686-1-_JPG.rf.100b13507c0141cf80c68a59ac1a2b08.jpg
#   inflating: Wind Turbine damage/valid/DJI_0687-1-_JPG.rf.07d48ea688e5e6c7e3b6ea08ee28ee34.jpg
#   inflating: Wind Turbine damage/valid/DJI_0688-1-_JPG.rf.a73f1789dcec47771d210869db5aa2d4.jpg
#   inflating: Wind Turbine damage/valid/DJI_0690-1-_JPG.rf.2c9f7ae217ede48279c07d17e5a4be59.jpg
#   inflating: Wind Turbine damage/valid/DJI_0691-1-_JPG.rf.7d86175d610f674bec55b9f5ca41ab50.jpg
#   inflating: Wind Turbine damage/valid/DJI_0693-1-_JPG.rf.9cf302352d7f7670800ffeb9a3e082b6.jpg
#   inflating: Wind Turbine damage/valid/DJI_0696-1-_JPG.rf.725a7a48d7c6a94bf1ddb029ccb9ed95.jpg
#   inflating: Wind Turbine damage/valid/DJI_0697-1-_JPG.rf.69e131131b26a3e418be7ae9d129fb51.jpg
#   inflating: Wind Turbine damage/valid/DJI_0698-1-_JPG.rf.bb2b186cff4d8892081d94f763cc2886.jpg
#   inflating: Wind Turbine damage/valid/DJI_0699-1-_JPG.rf.4bfa88489b63ff916926bd0eeae936d8.jpg
#   inflating: Wind Turbine damage/valid/DJI_0701-1-_JPG.rf.1964f477141aedbe4e515f5d2894bba2.jpg
#   inflating: Wind Turbine damage/valid/DJI_0705-1-_JPG.rf.476fc028afbd0309f055108fc01a1115.jpg
#   inflating: Wind Turbine damage/valid/DJI_0707-1-_JPG.rf.b9e2b0b10ac0f0368c97d8849a356eb2.jpg
#   inflating: Wind Turbine damage/valid/DJI_0708-1-_JPG.rf.ad43f15dd7a0a28041743686fa43ca66.jpg
#   inflating: Wind Turbine damage/valid/DJI_0710-1-_JPG.rf.71fd36b79566aea3da0af585a5e36ca7.jpg
#   inflating: Wind Turbine damage/valid/DJI_0711-1-_JPG.rf.934ded3410f4136458ecfff0c1a3353f.jpg
#   inflating: Wind Turbine damage/valid/DJI_0712-1-_JPG.rf.0415583fa0136f8f3c0b969b19dbd561.jpg
#   inflating: Wind Turbine damage/valid/DJI_0720-1-_JPG.rf.2790b8ea7bc3c4a23aaa7ef1fe06d2ff.jpg
#   inflating: Wind Turbine damage/valid/DJI_0721-1-_JPG.rf.abd7858604642dae89978fb1925ab3f5.jpg
#   inflating: Wind Turbine damage/valid/DJI_0722-1-_JPG.rf.dad8a3239732912724661d4151a11356.jpg
#   inflating: Wind Turbine damage/valid/DJI_0723-1-_JPG.rf.f3bef178676cc06bf3ac44345008dc87.jpg
#   inflating: Wind Turbine damage/valid/DJI_0725-1-_JPG.rf.5420f6514a7b94d2df6bffbbdaf196b9.jpg
#   inflating: Wind Turbine damage/valid/DJI_0729-1-_JPG.rf.22fa51c6bbd9f4540b5bbc5f1fe923cf.jpg
#   inflating: Wind Turbine damage/valid/DJI_0734-1-_JPG.rf.d8992a1057f665e240eb7b15a2d6c021.jpg
#   inflating: Wind Turbine damage/valid/DJI_0737-1-_JPG.rf.93724d5482d5cdf19643200d0aca8a2d.jpg
#   inflating: Wind Turbine damage/valid/DJI_0745-1-_JPG.rf.f856c44f035aac62b9c5fa0a74380e28.jpg
#   inflating: Wind Turbine damage/valid/DJI_0746-1-_JPG.rf.1535f0990cd2f872de4c9a639b0ad797.jpg
#   inflating: Wind Turbine damage/valid/DJI_0754-1-_JPG.rf.8e3d42b6ca7528d0578608e7343c4aa0.jpg
#   inflating: Wind Turbine damage/valid/DJI_0759-1-_JPG.rf.db8fbbea1ee4a6a46ecf6114915158bb.jpg
#   inflating: Wind Turbine damage/valid/DJI_0760-1-_JPG.rf.7857f604c1d892c3452120affba71c53.jpg
#   inflating: Wind Turbine damage/valid/DJI_0761-1-_JPG.rf.e15138dc90ffcc0ffbb8cbd8a4eb6436.jpg
#   inflating: Wind Turbine damage/valid/DJI_0763-1-_JPG.rf.984750fac251d1ff19c6821aa6845ab2.jpg
#   inflating: Wind Turbine damage/valid/DJI_0773_JPG.rf.2ceb50265e4a3fc73ae467d8c621de7b.jpg
#   inflating: Wind Turbine damage/valid/DJI_0776_JPG.rf.50d1b72a359746c242d6e09a3ada2d80.jpg
#   inflating: Wind Turbine damage/valid/DJI_0779_JPG.rf.1f9960908ded9cb3698902306299a18a.jpg
#   inflating: Wind Turbine damage/valid/DJI_0780_JPG.rf.fa8dbef815cd7dd7b58a9e513582c357.jpg
#   inflating: Wind Turbine damage/valid/DJI_0781_JPG.rf.8b552658c1b92a7af12d7eb1c02242f5.jpg
#   inflating: Wind Turbine damage/valid/DJI_0959_JPG.rf.61f8630c83db8531ab4d9e7d9ebefe8a.jpg
#   inflating: Wind Turbine damage/valid/DJI_0972_JPG.rf.cde6f6b0e28ee5df7936cdd3a62a964f.jpg
#   inflating: Wind Turbine damage/valid/DJI_0973_JPG.rf.50179850616a19cb463b93fb781d8fce.jpg
#   inflating: Wind Turbine damage/valid/DJI_0982_JPG.rf.0482cd9ce9b8c98b4b8b9469f20dade0.jpg
#   inflating: Wind Turbine damage/valid/DJI_0983_JPG.rf.820ecf933a71d0b629edcae16b50e97c.jpg
#   inflating: Wind Turbine damage/valid/DJI_0988_JPG.rf.15983cb4ea8350bc76faf531090be1cf.jpg
#   inflating: Wind Turbine damage/valid/_annotations.coco.json

# %%
import os
import json
import cv2
import numpy as np
from pathlib import Path
from tqdm import tqdm
import shutil
from ultralytics import YOLO
import pandas as pd
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
def load_coco_annotations(annotation_path):
    with open(annotation_path, 'r') as f:
        return json.load(f)

def convert_coco_to_yolo(coco_bbox, img_width, img_height):
    x, y, w, h = coco_bbox
    x_center = x + w/2
    y_center = y + h/2

    # Нормализация координат для YOLO формата
    x_center = x_center / img_width
    y_center = y_center / img_height
    w = w / img_width
    h = h / img_height

    return [x_center, y_center, w, h]

def process_image(image_path, annotation_data, type_folder, output_size=640, overlap=0.5):
    img = cv2.imread(image_path)
    img_height, img_width = img.shape[:2]

    image_id = next(img_info['id'] for img_info in annotation_data['images']
                   if img_info['file_name'] == os.path.basename(image_path))
    annotations = [ann for ann in annotation_data['annotations'] if ann['image_id'] == image_id]

    output_img_dir = Path(f'processed_dataset/images/{type_folder}')
    output_label_dir = Path(f'processed_dataset/labels/{type_folder}')
    output_img_dir.mkdir(parents=True, exist_ok=True)
    output_label_dir.mkdir(parents=True, exist_ok=True)

    step = int(output_size * (1 - overlap))

    counter = 0

    # Скользящее окно
    for y in range(0, img_height - output_size + 1, step):
        for x in range(0, img_width - output_size + 1, step):
            crop = img[y:y+output_size, x:x+output_size]

            yolo_annotations = []

            for ann in annotations:
                bbox = ann['bbox']
                category_id = ann['category_id']-1

                # Проверяем, находится ли bbox в текущем окне
                if (x <= bbox[0] <= x + output_size and
                    y <= bbox[1] <= y + output_size):

                    # Корректируем координаты bbox относительно окна
                    new_bbox = [
                        bbox[0] - x,
                        bbox[1] - y,
                        min(bbox[2], output_size - (bbox[0] - x)),  # Обрезаем если выходит за границы
                        min(bbox[3], output_size - (bbox[1] - y))   # Обрезаем если выходит за границы
                    ]

                    yolo_bbox = convert_coco_to_yolo(new_bbox, output_size, output_size)

                    # Проверяем, что все координаты в допустимом диапазоне [0, 1]
                    if all(0 <= coord <= 1 for coord in yolo_bbox):
                        yolo_annotations.append(f"{category_id} {' '.join(map(str, yolo_bbox))}")

            if yolo_annotations:
                output_img_path = output_img_dir / f"{Path(image_path).stem}_{counter}.jpg"
                cv2.imwrite(str(output_img_path), crop)

                output_label_path = output_label_dir / f"{Path(image_path).stem}_{counter}.txt"
                with open(output_label_path, 'w') as f:
                    f.write('\n'.join(yolo_annotations))

                counter += 1

def process_dataset(input_dir, annotation_path, type_folder):
    # Загружаем аннотации COCO
    annotation_data = load_coco_annotations(annotation_path)

    for img_path in tqdm(list(Path(input_dir).glob('*.jpg'))):
        process_image(str(img_path), annotation_data, type_folder)


def train_yolov8():
    # Создаем файл конфигурации датасета
    dataset_yaml = """
    path: /kaggle/working/processed_dataset/
    train: images/train
    val: images/valid
    names:
      0: corrosion
      1: lightning
      2: lightning receptor
      3: missing teeth
      4: patch
    """

    with open('/kaggle/working/dataset.yaml', 'w') as f:
        f.write(dataset_yaml)

    # MARAT: model = YOLO(yolov8l.pt) model.train(data='dataset.yaml', epochs=200, imgsz=640, batch=8, save_period=25, exist_ok=True, project="detect_turbines", name="yolo8-detect")
    # ЧТОБЫ ПРОДОЛЖИТЬ НАДО В КОННЦЕ model.train(..., resume=True) ДОБАВИТЬ resume=True
    # ГОША: тебе нужно закинуть epoch60.pt в корень и запустить
    model = YOLO('/kaggle/input/epoch90/pytorch/default/1/epoch90.pt') #  yolov8n.pt

    model.train(data='dataset.yaml', epochs=150, imgsz=640, batch=16, save_period=15, exist_ok=True,project="detect_turbines", name="yolo8-detect", resume = True)

# %%
# Один раз запускается (второй раз не перезапускать!!!)
process_dataset("Wind Turbine damage/train", "Wind Turbine damage/train/_annotations.coco.json", "train")
process_dataset("Wind Turbine damage/valid", "Wind Turbine damage/valid/_annotations.coco.json", "valid")
# Out:
# 100%|██████████| 1070/1070 [01:34<00:00, 11.33it/s]
# 100%|██████████| 271/271 [00:16<00:00, 16.86it/s]

# %%
train_yolov8()
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset.yaml, degrees=0.0, deterministic=True, device=cuda:0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=150, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/input/epoch90/pytorch/default/1/epoch90.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo8-detect, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=detect_turbines, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=detect_turbines/yolo8-detect, save_frames=False, save_json=False, save_period=15, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# Model summary: 129 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1761.7±674.1 MB/s, size: 81.9 KB)
# train: Scanning /kaggle/working/processed_dataset/labels/train.cache... 9250 images, 0 backgrounds, 0 corrupt: 100%|██████████| 9250/9250 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 573.2±278.1 MB/s, size: 78.8 KB)
# val: Scanning /kaggle/working/processed_dataset/labels/valid.cache... 2212 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2212/2212 [00:00<?, ?it/s]
# Plotting labels to detect_turbines/yolo8-detect/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to detect_turbines/yolo8-detect
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      2.08G      1.329     0.8197     0.9738         45        640:  10%|▉         | 56/579 [00:09<01:32,  5.67it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_31/4212058578.py in <cell line: 0>()
# ----> 1 train_yolov8()
#
# /tmp/ipykernel_31/2656237364.py in train_yolov8()
#     102     model = YOLO('/kaggle/input/epoch90/pytorch/default/1/epoch90.pt') #  yolov8n.pt
#     103
# --> 104     model.train(data='dataset.yaml', epochs=150, imgsz=640, batch=16, save_period=15, exist_ok=True,project="detect_turbines", name="yolo8-detect")
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     791
#     792         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 793         self.trainer.train()
#     794         # Update model and cfg after training
#     795         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in train(self)
#     209
#     210         else:
# --> 211             self._do_train(world_size)
#     212
#     213     def _setup_scheduler(self):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     392
#     393                 # Backward
# --> 394                 self.scaler.scale(self.loss).backward()
#     395
#     396                 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Submit

# %%
# !gdown 1ePuyQSNw6FrvfsOcL0h2Z79d-VD2bgwf
# !unzip sample_submission_with_errors.csv.zip
# !rm sample_submission_with_errors.csv.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ePuyQSNw6FrvfsOcL0h2Z79d-VD2bgwf
# To: /kaggle/working/sample_submission_with_errors.csv.zip
# 100%|██████████████████████████████████████| 55.4k/55.4k [00:00<00:00, 64.1MB/s]
# Archive:  sample_submission_with_errors.csv.zip
#   inflating: sample_submission_with_errors.csv
#   inflating: __MACOSX/._sample_submission_with_errors.csv

# %%
def process_image_for_inference(image_path, model, output_size=640, overlap=0.5):
    img = cv2.imread(image_path)
    img_height, img_width = img.shape[:2]

    # Создаем временную директорию для обработанных изображений
    temp_dir = Path('temp_inference')
    temp_dir.mkdir(exist_ok=True)

    # Размер шага с учетом перекрытия
    step = int(output_size * (1 - overlap))

    class_names = [
    "corrosion",
    "lightning",
    "lightning receptor",
    "missing teeth",
    "patch"
    ]

    predictions = []

    # Скользящее окно
    for y in range(0, img_height - output_size + 1, step):
        for x in range(0, img_width - output_size + 1, step):
            crop = img[y:y+output_size, x:x+output_size]

            temp_img_path = temp_dir / f"{Path(image_path).stem}_temp.jpg"
            cv2.imwrite(str(temp_img_path), crop)

            results = model(temp_img_path, verbose=False)

            for result in results:
                boxes = result.boxes

                for box in boxes:
                    class_index = int(box.cls[0].cpu().numpy())
                    class_name = class_names[class_index]
                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                    conf = float(box.conf[0].cpu().numpy())

                    # Переводим координаты в исходную систему координат
                    x1 = float(x1 + x)
                    y1 = float(y1 + y)
                    x2 = float(x2 + x)
                    y2 = float(y2 + y)

                    # Формируем bbox в формате [x, y, width, height]
                    bbox = [x1, y1, x2 - x1, y2 - y1]

                    predictions.append([f'"{class_name}"'] + bbox + [conf])

    shutil.rmtree(temp_dir)

    return predictions

def create_submission_file(predictions, output_file='submission.csv'):
    df = pd.DataFrame(predictions)
    df.to_csv(output_file, index=False, sep=',')

# %%
model = YOLO('/kaggle/working/detect_turbines/yolo8-detect/weights/last.pt')

df_example = pd.read_csv("/kaggle/input/sample/sample_submission_with_errors.csv")
images = df_example["image_id"].to_list()

results = []
for image_id in tqdm(images):
    img_path = os.path.join("Wind Turbine damage", "test", image_id)
    predictions = process_image_for_inference(str(img_path), model)
    results.append({"image_id": str(image_id), "objects": str(predictions)})

create_submission_file(results)
# Out:
# 100%|██████████| 151/151 [02:31<00:00,  1.01s/it]

# %%
df_sub = pd.read_csv("/content/submission.csv") # НУЖНО СКАЧАТЬ submission.csv и удалить через ctrl F все кавычки одинарные иначе сабмит не зайдет '

# %%
df_example.head(5)

# %%
df_sub.head(5)
